// %%
%jsroot on

// %%
TFile *f = TFile::Open(“histogram1.root”);
// Out:
// input_line_134:2:25: error: non-ASCII characters are not allowed outside of literals and identifiers
//  TFile *f = TFile::Open(“histogram1.root”);
//                         ^
// input_line_134:2:28: error: use of undeclared identifier 'histogram1'
//  TFile *f = TFile::Open(“histogram1.root”);
//                          ^
// input_line_134:2:43: error: non-ASCII characters are not allowed outside of literals and identifiers
//  TFile *f = TFile::Open(“histogram1.root”);
//                                         ^
